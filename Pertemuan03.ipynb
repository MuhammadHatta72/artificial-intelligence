# %%
#Breath First Search

graph = {
    'A' : ['B', 'C'],
    'B' : ['D', 'E', 'C'],
    'C' : ['F'],
    'D' : [],
    'E' : ['F'],
    'F' : ['H'],
    'G' : ['H'],
    'H' : ['G'],
}

visited = []
queue = []

def bfs(visited, graph, node):
  visited.append(node)
  queue.append(node)

  while queue:
    s = queue.pop(0)
    print (s, end = " ")

    for neighbour in graph[s]:
      if neighbour not in visited:
        visited.append(neighbour)
        queue.append(neighbour)

print("Hasil penelusuran graf menggunakan BFS")
bfs(visited, graph, 'A')
# Out:
# Hasil penelusuran graf menggunakan BFS
# A B C D E F H G

# %%
#Depth First Search

graph = {
    'A' : ['B', 'C'],
    'B' : ['C', 'D', 'E'],
    'C' : ['F'],
    'D' : [],
    'E' : ['F'],
    'F' : ['H'],
    'G' : ['H'],
    'H' : ['G'],
}

visited = set()

def dfs(visited, graph, node):
  if node not in visited:
    print(node)
    visited.add(node)
    for neighbour in graph[node]:
        dfs(visited, graph, neighbour)

print("Hasil penelusuran graf menggunakan DFS")
dfs(visited, graph, 'A')
# Out:
# Hasil penelusuran graf menggunakan DFS
# A
# B
# C
# F
# H
# G
# D
# E

# %%
#Latihan Pratikum 1
graph = {
    'A' : ['B', 'E', 'F'],
    'B' : ['A', 'G', 'F'],
    'E' : ['A', 'F'],
    'F' : ['A', 'B', 'E',],
    'G' : ['C', 'H'],
    'C' : ['D', 'G'],
    'H' : ['D', 'G'],
    'D' : ['C', 'H'],
}

visitedbfs = []
queue = []

def bfs(visitedbfs, graph, node):
  visitedbfs.append(node)
  queue.append(node)

  while queue:
    s = queue.pop(0)
    print (s, end = " ")

    for neighbour in graph[s]:
      if neighbour not in visitedbfs:
        visitedbfs.append(neighbour)
        queue.append(neighbour)

visiteddfs = set()

def dfs(visiteddfs, graph, node):
  if node not in visiteddfs:
    print (node, end = " ")
    visiteddfs.add(node)
    for neighbour in graph[node]:
        dfs(visiteddfs, graph, neighbour)

print("Hasil penelusuran graf menggunakan BFS")
bfs(visitedbfs, graph, 'A')

print("\n--------------------------------------")

print("Hasil penelusuran graf menggunakan DFS")
dfs(visiteddfs, graph, 'A')
# Out:
# Hasil penelusuran graf menggunakan BFS
# A B E F G C H D
# --------------------------------------
# Hasil penelusuran graf menggunakan DFS
# A B G C D H F E

# %%
#Latihan Pratikum 2
graph = {
    'A' : ['B',],
    'B' : ['A', 'G', 'F'],
    'F' : ['B', 'E'],
    'E' : ['F'],
    'G' : ['B', 'C'],
    'C' : ['D', 'G'],
    'D' : ['C', 'H'],
    'H' : ['D'],
}

visitedbfs = []
queue = []

def bfs(visitedbfs, graph, node):
  visitedbfs.append(node)
  queue.append(node)

  i = 0
  while queue:
    s = queue.pop(0)
    i += 1
    if s == "D":
      print("D STEP-", i)
    print (s, end = " ")

    for neighbour in graph[s]:
      if neighbour not in visitedbfs:
        visitedbfs.append(neighbour)
        queue.append(neighbour)

visiteddfs = set()

j = 0
def dfs(visiteddfs, graph, node, j):
  if node not in visiteddfs:
    if node == "D":
      print("D STEP-", j)
    print (node, end = " ")
    j += 1
    visiteddfs.add(node)
    for neighbour in graph[node]:
        dfs(visiteddfs, graph, neighbour, j)

print("Hasil penelusuran graf menggunakan BFS")
bfs(visitedbfs, graph, 'A')

print("\n--------------------------------------")

print("Hasil penelusuran graf menggunakan DFS")
dfs(visiteddfs, graph, 'A', j)
# Out:
# Hasil penelusuran graf menggunakan BFS
# A B G F C E D STEP- 7
# D H
# --------------------------------------
# Hasil penelusuran graf menggunakan DFS
# A B G C D STEP- 4
# D H F E
